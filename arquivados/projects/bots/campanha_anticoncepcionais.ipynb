# %%
import pandas as pd
from tqdm import tqdm
from time import sleep
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from password import passwordTrier

# %%
from functions import *

# %%
#df_precos = gera_arquivo_dados_produtos("anticoncepcionais",categoria=1)
# Out:
#     codshopfarma                           produto laboratorio           ean
# 0         112695      ADOLESS 0,060MG+0,015MG 28CP   FQM GRUPO  7.898040e+12
# 1         108423      ADOLESS 0,060MG+0,015MG 84CP   FQM GRUPO  7.898040e+12
# 3          13094          AIXA 2MG+0,03MG 63CP REV      SANOFI  7.896423e+12
# 4         113661     ALGESTONA AC+ENAN EST INJ 1ML     CIFARMA  7.898505e+12
# 5          14420     ALGESTONA AC+ENAN EST INJ 1ML     LEGRAND  7.894916e+12
# ..           ...                               ...         ...           ...
# 239        18172        YASMIN 3MG+0,03MG 63CP REV    BAYER SA  7.891107e+12
# 240       129803         YAZ 3MG+0,02MG 24+4CP REV    BAYER SA  7.891107e+12
# 241        10741           YAZ 3MG+0,02MG 24CP REV    BAYER SA  7.891107e+12
# 242        18171      YAZ FLEX 3MG+0,02MG 30CP REV    BAYER SA  7.891107e+12
# 243        55566      YAZ FLEX 3MG+0,02MG 30CP REV    BAYER SA  7.891107e+12
#
# [242 rows x 4 columns]
# ...

# %%
#df_precos.to_excel('anticoncepcionais2.xlsx')

# %%
df = pd.read_excel('anticoncepcionais2.xlsx')
df
# Out:
#      Unnamed: 0            ean                           produto laboratorio  \
# 0             0  7898040320683      ADOLESS 0,060MG+0,015MG 28CP   FQM GRUPO
# 1             1  7898040322137      ADOLESS 0,060MG+0,015MG 84CP   FQM GRUPO
# 2             2  7896422532228          AIXA 2MG+0,03MG 63CP REV      SANOFI
# 3             3  7898505092506     ALGESTONA AC+ENAN EST INJ 1ML     CIFARMA
# 4             4  7894916142809     ALGESTONA AC+ENAN EST INJ 1ML     LEGRAND
# ..          ...            ...                               ...         ...
# 235         236  7891106914109        YASMIN 3MG+0,03MG 63CP REV    BAYER SA
# 236         238  7891106914154         YAZ 3MG+0,02MG 24+4CP REV    BAYER SA
# 237         239  7891106914147           YAZ 3MG+0,02MG 24CP REV    BAYER SA
# 238         240  7891106908498      YAZ FLEX 3MG+0,02MG 30CP REV    BAYER SA
# 239         241  7891106914178      YAZ FLEX 3MG+0,02MG 30CP REV    BAYER SA
#
# ...

# %%
#inclui_preco_promocao(df, 'Campanha Inverno Anticoncepcionais', data_inicial='07/04/2024', data_final='31/10/2024')
# Out:
# 100%|██████████| 240/240 [16:50<00:00,  4.21s/it]
