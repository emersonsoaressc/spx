# %%
import pandas as pd
from tqdm import tqdm
from time import sleep
from password import passwordTrier
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
options = webdriver.ChromeOptions()
options.add_argument("--headless")
login_trier, password_trier = passwordTrier()
from functions import *

# %%
df = pd.read_excel('arquivados\precos_protetores.xlsx')
df
# Out:
#       codshopfarma                  Descrição Produto    Laboratório  \
# 0    7896681861381     PERFECT SUN GEL FIXA BRONZE PO            NaN
# 1    7896658035586       PROFUSE PROT F30 ENSOLEI 50G           ACHE
# 2    7898567703488          BRONZ SUN PRIME F15 150ML      AEROFLEX
# 3    7898567703518       PROT SUN PRIME F30 SPR 150ML      AEROFLEX
# 4    7898567703976       PROT SUN PRIME F30 SPR 370ML      AEROFLEX
# ..             ...                                ...            ...
# 205  3282770206050        PROT ACTINE F60 TOQ SEC 40G  PIERRE FABRE
# 206  3282770153811         PROT ACTINE FRESH F30 150G  PIERRE FABRE
# 207  3282770207699        PROT ACTINE F70 TOQ SEC 40G  PIERRE FABRE
# 208  7898910451950        BB CREAM MAX SOL F30 MD 60G       VITALIFE
# 209  7898910451745     PROT MAX SOL F60 CHA VER 120ML       VITALIFE
#
#      Preço Custo  Margem  preco_shopfarma   Raia     PP  PANVEL  São Joao  \
# ...

# %%
inclui_preco_promocao(df, 'Campanha Protetores', data_inicial='20/12/2023', data_final='10/01/2024', filial=9)
# Out:
# 100%|██████████| 210/210 [15:15<00:00,  4.36s/it]
