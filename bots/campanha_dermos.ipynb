# %%
import pandas as pd
from tqdm import tqdm
from time import sleep
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from password import passwordTrier

# %%
from functions import *

# %%
df_precos = gera_arquivo_dados_produtos("dermos",depto="12")
# Out:
#     codshopfarma                            produto    laboratorio  \
# 0         142444     A-OXITIVE AVENE NOITE SER 30ML  PIERRE FABRE
# 1         139308     ACTINE GEL LIMP PELE ACNE 140G  PIERRE FABRE
# 2         136016        ACTINE LOCAO ADSTRING 190ML  PIERRE FABRE
# 3         133471      ACTINE PROT SOLAR F60 SEC 40G  PIERRE FABRE
# 4         142442     ACTINE TRAT GEL PEL ACNEIC 30G  PIERRE FABRE
# ..           ...                                ...            ...
# 778       140895      VICHY SERUM FAC MIN PREB 30ML     LOREAL/DCA
# 779       136023       VICHY SERUM FAC MINERAL 30ML     LOREAL/DCA
# 780       140894       VICHY SERUM FAC MINERAL 50ML     LOREAL/DCA
# 781       135053     VICHY SERUM MINERAL OLHOS 15ML     LOREAL/DCA
# 782       130378     VICHY SH DERCOS ANTIQUED 400ML     LOREAL/DCA
#
#               ean
# 0    3.282770e+12
# 1    3.282770e+12
# 2    7.896290e+12
# 3    3.282770e+12
# 4    3.282770e+12
# ..            ...
# 778  3.337876e+12
# ...

# %%
df = pd.read_excel('dermos2.xlsx')
df
# Out:
#      Unnamed: 0            ean                            produto laboratorio  \
# 0           611  7891010248314       PROT MINESOL F60 UNIF CL 40G  JOHNSON &
# 1           612  7891010248345      PROT MINESOL F60 UNIF MOR 40G  JOHNSON &
# 2           613  7891010254032       PROT MINESOL F70 COR&RO 200M  JOHNSON &
# 3           614  7891010250799           PROT MINESOL F70 MOR 40G  JOHNSON &
# 4           615  7891010250812           PROT MINESOL F70 NEG 40G  JOHNSON &
# ..          ...            ...                                ...         ...
# 162         773  3337875762908      VICHY SERUM FAC MIN PREB 30ML  LOREAL/DCA
# 163         774  3337875594516       VICHY SERUM FAC MINERAL 30ML  LOREAL/DCA
# 164         775  3337875543248       VICHY SERUM FAC MINERAL 50ML  LOREAL/DCA
# 165         776  3337875596763     VICHY SERUM MINERAL OLHOS 15ML  LOREAL/DCA
# 166         777  7899706179607     VICHY SH DERCOS ANTIQUED 400ML  LOREAL/DCA
#
# ...

# %%
inclui_preco_promocao(df, 'Campanha Dermo Abril', data_inicial='07/04/2024', data_final='30/04/2024')
# Out:
# 100%|██████████| 167/167 [11:43<00:00,  4.21s/it]
